# %% [markdown]
# # Correlation analysis between the Bitcoin currency and Twitter
#
# This project consists of a correlation analysis between the Bitcoin currency and tweets. In order to define the positiveness of a tweet (if the course of the bitcoin will go up or down), we realise a sentiment analysis of each tweet using the VADER algorithm. Finally we try to find a correlation between the two and we will make some machine learning to make predictions.
#
# This notebook was written using Python 3.6.

# %% [markdown]
# ## Import the Python dependencies
# For this project we need Pandas to manage all of our datasets.
#
# You will need to run the following commands with pip to install the dependencies:
#
# ```
# pip install VaderSentiment
# pip install pandas
# ```
#
# You can also run `pip install .` from the project's root folder to install all the requirements from the `requirements.txt` file.

# %%
import json
import pandas as pd
import io
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
import numpy as np
import matplotlib.pyplot as plt
import glob
from tqdm import tnrange, tqdm_notebook, tqdm

# %% [markdown]
# ## Load the datasets
# We read the data generated from two other notebooks, TwitterExtraction and CryptoCurrencyExtraction. The data is stored in 2 CSV files. The first one contains around 430'000 tweets all related to the Bitcoin on a period of 10 days between the 10.05.2018 and the 20.05.2018. The second dataset contains the historical data of the exchange rate between Bitcoin and USD over the same period of time.

# %%
tweets = pd.read_csv('tweets_clean.csv')

# Drop duplicate tweets
print('tweet shape before droping duplicates', tweets.shape)
duplicates_removed = tweets.shape[0]
tweets = tweets.drop_duplicates(subset=['ID'])
duplicates_removed -= tweets.shape[0]
print('tweet shape after droping duplicates', tweets.shape)
print('duplicates removed', duplicates_removed)

tweets.head(5)
# Out:
# tweet shape before droping duplicates (428973, 7)
# tweet shape after droping duplicates (423849, 7)
# duplicates removed 5124
#                    ID                                               Text  \
# 0  998140768622596097  RT : Check out our new bounty program on Bitco...
# 1  998140767016173569  RT : GIN CASH early backers bounty distributio...
# 2  998140757872529408  RT : Here’s a sneak peak, the title:‘My Tweet ...
# 3  998140749114888192  RT : GIN CASH early backers bounty distributio...
# 4  998140746493505536  RT : PO8 CMO Raul Vasquez and ICON  Co-Founder...
#
#          UserName  UserFollowerCount  RetweetCount  Likes  \
# 0    Neaj Morshed                 88          2080      0
# 1  Ирина Абрамова                  0          4125      0
# 2           julia                 10            35      0
# 3     Tan Booking                186          4125      0
# 4        gospetig                 23           469      0
#
#                         CreatedAt
# 0  Sun May 20 09:57:58 +0000 2018
# 1  Sun May 20 09:57:58 +0000 2018
# 2  Sun May 20 09:57:55 +0000 2018
# 3  Sun May 20 09:57:53 +0000 2018
# 4  Sun May 20 09:57:53 +0000 2018

# %%
CRYPTO_SYMBOL = 'BTC'
CRYPTO_FOLDER = f"data/crypto/{CRYPTO_SYMBOL}"
crypto_files = glob.glob(f"{CRYPTO_FOLDER}/*.csv")
dfs = []
for file in crypto_files:
    dfs.append(pd.read_csv(file))
df_btc = pd.concat(dfs)
df_btc = df_btc.sort_values(by=['time'])

df_btc.shape

#btc_usd = pd.read_csv('data/crypto/BTC/2018-05-11 11-55-00~2018-05-18 10-29-00.csv')
btc_usd = df_btc
# Drop duplicates
print('bitcoin shape before droping duplicates', btc_usd.shape)
duplicates_removed = btc_usd.shape[0]
btc_usd = btc_usd.drop_duplicates(subset=['time'])
print('bitcoin shape after droping duplicates', btc_usd.shape)
duplicates_removed -= btc_usd.shape[0]
print('duplicates removed', duplicates_removed)
btc_usd.head(5)
# Out:
# bitcoin shape before droping duplicates (20317, 5)
# bitcoin shape after droping duplicates (20302, 5)
# duplicates removed 15
#      close     high      low     open        time
# 0  8737.87  8747.28  8737.63  8745.27  1526032500
# 1  8745.14  8745.14  8737.76  8738.79  1526032560
# 2  8748.48  8753.09  8744.79  8745.14  1526032620
# 3  8746.25  8748.76  8742.89  8748.48  1526032680
# 4  8753.83  8753.86  8743.80  8746.25  1526032740

# %% [markdown]
# ## Sentiment analysis
#
# ### VADER
# VADER (Valence Aware Dictionary and sEntiment Reasoner) is a lexicon and rule-based sentiment analysis tool that is specifically attuned to sentiments expressed in social media.
#
# VADER takes into account
# - negations and contractions (not good, wasn’t good)
# - Ponctuation (good!!!), CAPS, emotes :), emojis
# - Intensificators (very, kind of), acronyms ‘lol’
# - Scores between -1.0 (negative) and 1.0 (positive)
#
# We will use this sentiment analysis of the tweets to calculate a score that will represent the importance of each tweet.

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()
compound = []
for i,s in enumerate(tqdm(tweets['Text'])):
    vs = analyzer.polarity_scores(s)
    compound.append(vs["compound"])
tweets["compound"] = compound
tweets.head(5)
# Out:
# 100%|██████████| 423849/423849 [01:40<00:00, 4218.37it/s]
#                                      ID  \
# CreatedAt
# 2018-05-20 09:57:58  998140768622596097
# 2018-05-20 09:57:58  998140767016173569
# 2018-05-20 09:57:55  998140757872529408
# 2018-05-20 09:57:53  998140749114888192
# 2018-05-20 09:57:53  998140746493505536
#
#                                                                   Text  \
# CreatedAt
# 2018-05-20 09:57:58  RT : Check out our new bounty program on Bitco...
# 2018-05-20 09:57:58  RT : GIN CASH early backers bounty distributio...
# 2018-05-20 09:57:55  RT : Here’s a sneak peak, the title:‘My Tweet ...
# 2018-05-20 09:57:53  RT : GIN CASH early backers bounty distributio...
# 2018-05-20 09:57:53  RT : PO8 CMO Raul Vasquez and ICON  Co-Founder...
#
#                            UserName  UserFollowerCount  RetweetCount  Likes  \
# CreatedAt
# 2018-05-20 09:57:58    Neaj Morshed                 88          2080      0
# 2018-05-20 09:57:58  Ирина Абрамова                  0          4125      0
# 2018-05-20 09:57:55           julia                 10            35      0
# 2018-05-20 09:57:53     Tan Booking                186          4125      0
# 2018-05-20 09:57:53        gospetig                 23           469      0
#
#                               CreatedAt  compound   Scores
# CreatedAt
# 2018-05-20 09:57:58 2018-05-20 09:57:58    0.4767  42.4263
# 2018-05-20 09:57:58 2018-05-20 09:57:58    0.0000   0.0000
# 2018-05-20 09:57:55 2018-05-20 09:57:55    0.2023   2.2253
# 2018-05-20 09:57:53 2018-05-20 09:57:53    0.0000   0.0000
# 2018-05-20 09:57:53 2018-05-20 09:57:53    0.0000   0.0000

# %% [markdown]
# ### Calculate a score for each tweet
# To calculate the score for each tweet, we use different variables to which we had a weight based on its importance.
#
# The compound column represents the sentiment of the tweets and its value is between -1 and 1.
#
# We also use the number of retweets, the number of likes, and the number of users that follow the tweet's author.

# %%
scores = []
for i, s in tqdm(tweets.iterrows(), total=tweets.shape[0]):
    scores.append(s["compound"] * ((s["UserFollowerCount"]+1)) * ((s["Likes"]+1)))
tweets["Scores"] = scores
tweets.head(5)
# Out:
# 100%|██████████| 423849/423849 [00:35<00:00, 11934.99it/s]
#                                      ID  \
# CreatedAt
# 2018-05-20 09:57:58  998140768622596097
# 2018-05-20 09:57:58  998140767016173569
# 2018-05-20 09:57:55  998140757872529408
# 2018-05-20 09:57:53  998140749114888192
# 2018-05-20 09:57:53  998140746493505536
#
#                                                                   Text  \
# CreatedAt
# 2018-05-20 09:57:58  RT : Check out our new bounty program on Bitco...
# 2018-05-20 09:57:58  RT : GIN CASH early backers bounty distributio...
# 2018-05-20 09:57:55  RT : Here’s a sneak peak, the title:‘My Tweet ...
# 2018-05-20 09:57:53  RT : GIN CASH early backers bounty distributio...
# 2018-05-20 09:57:53  RT : PO8 CMO Raul Vasquez and ICON  Co-Founder...
#
#                            UserName  UserFollowerCount  RetweetCount  Likes  \
# CreatedAt
# 2018-05-20 09:57:58    Neaj Morshed                 88          2080      0
# 2018-05-20 09:57:58  Ирина Абрамова                  0          4125      0
# 2018-05-20 09:57:55           julia                 10            35      0
# 2018-05-20 09:57:53     Tan Booking                186          4125      0
# 2018-05-20 09:57:53        gospetig                 23           469      0
#
#                               CreatedAt  compound   Scores
# CreatedAt
# 2018-05-20 09:57:58 2018-05-20 09:57:58    0.4767  42.4263
# 2018-05-20 09:57:58 2018-05-20 09:57:58    0.0000   0.0000
# 2018-05-20 09:57:55 2018-05-20 09:57:55    0.2023   2.2253
# 2018-05-20 09:57:53 2018-05-20 09:57:53    0.0000   0.0000
# 2018-05-20 09:57:53 2018-05-20 09:57:53    0.0000   0.0000

# %%
tweets.tail(100)
# Out:
#                                      ID  \
# CreatedAt
# 2018-05-10 14:15:35  994581721910775809
# 2018-05-10 14:15:32  994581707176202240
# 2018-05-10 14:15:17  994581647675875328
# 2018-05-10 14:14:59  994581572056764416
# 2018-05-10 14:14:56  994581557775134720
# 2018-05-10 14:14:46  994581515068739584
# 2018-05-10 14:14:41  994581493564534789
# 2018-05-10 14:13:57  994581311347134465
# 2018-05-10 14:13:51  994581285111771136
# 2018-05-10 14:13:47  994581269173456896
# 2018-05-10 14:13:36  994581221547151361
# 2018-05-10 14:13:35  994581216925020161
# 2018-05-10 14:12:57  994581058040446976
# 2018-05-10 14:12:57  994581057067417600
# 2018-05-10 14:12:55  994581050180423680
# 2018-05-10 14:12:33  994580957385588736
# 2018-05-10 14:12:20  994580904927350785
# 2018-05-10 14:12:05  994580842017185792
# 2018-05-10 14:12:00  994580821502652421
# 2018-05-10 14:12:00  994580819476992000
# 2018-05-10 14:11:52  994580785129701377
# 2018-05-10 14:11:36  994580718872244224
# 2018-05-10 14:11:33  994580706952204288
# 2018-05-10 14:11:06  994580591340273664
# 2018-05-10 14:12:20       0.0000
# 2018-05-10 14:12:05       0.0000
# 2018-05-10 14:12:00       0.0000
# 2018-05-10 14:12:00     -37.7016
# 2018-05-10 14:11:52      16.3392
# 2018-05-10 14:11:36       0.0000
# 2018-05-10 14:11:33    1541.9136
# 2018-05-10 14:11:06    5408.0424
# 2018-05-10 14:11:05      53.3974
# 2018-05-10 14:10:49       0.0000
# 2018-05-10 14:10:27       0.0000
# 2018-05-10 14:10:20       0.0000
# 2018-05-10 14:09:42  567636.5856
# 2018-05-10 14:09:17       0.0000
# ...                          ...
# 2018-05-10 14:00:10  477425.7492
# 2018-05-10 14:00:02     156.0384
# 2018-05-10 13:59:38     280.1600
# 2018-05-10 13:59:36     425.0000
# 2018-05-10 13:59:03     -48.7500
# 2018-05-10 13:58:51      89.5776
# 2018-05-10 13:58:49      11.6685
# 2018-05-10 13:58:38      31.0534
# 2018-05-10 13:58:36       0.0000
# 2018-05-10 13:58:18       0.0000
# 2018-05-10 13:57:56    -134.5749
# 2018-05-10 13:57:54       5.1471
# 2018-05-10 13:57:46       0.0000
# 2018-05-10 13:57:31      33.5424
# 2018-05-10 13:56:38      76.4573
# 2018-05-10 13:55:48       0.0000
# 2018-05-10 13:55:40    5024.7604
# 2018-05-10 13:54:58       0.0000
# 2018-05-10 13:54:49    2647.1662
# 2018-05-10 13:54:18       0.0000
# 2018-05-10 13:54:17       0.0000
# 2018-05-10 13:53:50       0.0000
# 2018-05-10 13:53:27    8862.3612
# 2018-05-10 13:53:05    -719.1320
# 2018-05-10 13:52:38       0.0000
# 2018-05-10 13:52:31      24.0416
# 2018-05-10 13:52:17      14.2650
# 2018-05-10 13:52:15      28.4160
# 2018-05-10 13:52:06       0.0000
# 2018-05-10 13:51:06       0.0000
#
# [100 rows x 9 columns]

# %% [markdown]
# ## Group by and sum by 5 minutes

# %%
tweets['CreatedAt'] = pd.to_datetime(tweets['CreatedAt'])
tweets.index = tweets['CreatedAt']

tweets_grouped = tweets.groupby(pd.TimeGrouper('1h'))['Scores'].sum()

btc_usd['time'] = pd.to_datetime(btc_usd['time'], unit='s')
btc_usd.index = btc_usd['time']

btc_usd_grouped = btc_usd.groupby(pd.TimeGrouper('1h'))['close'].mean()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %% [markdown]
# ### Plotting the scores
# We calculate the mean of each tweets grouped by hour and then we plot it.

# %%
#
#plt.plot_date(tweets_grouped.index, tweets_grouped, ls='-', marker='o')
#plt.plot_date(btc_usd_grouped.index, btc_usd_grouped, ls='-', marker='o')
#plt.show()

fig, ax1 = plt.subplots(figsize=(20,10))

ax2 = ax1.twinx()
ax1.plot_date(tweets_grouped.index, tweets_grouped, 'g-')
ax2.plot_date(btc_usd_grouped.index, btc_usd_grouped, 'b-')

ax1.set_xlabel('X data')
ax1.set_ylabel('Y1 data', color='g')
ax2.set_ylabel('Y2 data', color='b')
plt.show()

# %% [markdown]
# ## Correlation analysis
# Here we make the correlation analysis between BTC/USD currency derivative and the tweets scores derivative.
#
# We can test our correlation hypothesis using the Pandas corr() method, which computes a Pearson correlation coefficient for each column in the dataframe against each other column.
#
# This Stackoverflow answer gives very useful details about correlating with time series.
# https://stackoverflow.com/questions/6467832/how-to-get-the-correlation-between-two-timeseries-using-pandas

# %%
tweets_grouped.corr(btc_usd_grouped)
# Out:
# 0.097433800514633601

# %% [markdown]
# ### Derivative and offset
# We will need a bit more complicated correlation analysis here as we need to correlate the derivative of both series and we will need to offset each serie from the other because the change increase in the Bitcoin currency should occure a few moments after the tweets. The task here is to find a good offset.

# %%
#Derivative and normalisation???

#Offset

#Correlation

# %% [markdown]
# ## Machine learning with Spark

# %% [markdown]
# ## Realtime correlation viewer
# We can stream the new tweets about Bitcoin using the TwythonStreamer module.
#
# Using the CryptoCompare API we can also retrieve the BTC/USD currency in realtime using sockets.
#
# Finally we can plot it with Plotly.

# %%
import plotly.plotly as py
import plotly.graph_objs as go
from datetime import datetime
from time import sleep
import plotly.tools as tls  

# Plot the real-time series graph

# Get stream id from stream id list
stream_id_crypto, stream_id_tweets = tls.get_credentials_file()['stream_ids'][:2]

# Make instance of stream id object 
stream_crypto = go.Stream(
    token=stream_id_crypto,  # link stream id to 'token' key
    maxpoints=200      # keep a max of 80 pts on screen
)

stream_tweets = go.Stream(
    token=stream_id_tweets,  # link stream id to 'token' key
    maxpoints=200      # keep a max of 80 pts on screen
)


# Initialize trace of streaming plot by embedding the unique stream_id
trace_crypto = go.Ohlc(x=[], open=[], high=[], low=[], close=[], stream=stream_crypto, name = CRYPTO_SYMBOL)
trace_tweets = go.Scatter(x=[], y=[], mode='lines', name='Sentiments', yaxis='y2', stream=stream_tweets)

data = [trace_crypto, trace_tweets]

# Add title to layout object
layout = go.Layout(
    title=f"{CRYPTO_SYMBOL} currency and tweets sentiments",
    yaxis=dict(
        title='Price USD'
    ),
    yaxis2=dict(
        title='Sentiment score',
        titlefont=dict(
            color='rgb(148, 103, 189)'
        ),
        tickfont=dict(
            color='rgb(148, 103, 189)'
        ),
        overlaying='y',
        side='right'
    )
)

# Make a figure object
fig = go.Figure(data=data, layout=layout)

py.iplot(fig, filename=f"real_time_{CRYPTO_SYMBOL}_tweets")
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~SebastienRichoz/60.embed" height="525px" width="100%"></iframe>

# %%
from twython import TwythonStreamer
import time
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer


# We will provide the stream link object the same token that's associated with the trace we wish to stream to
#s_crypto = py.Stream(stream_id_crypto)
s_tweets = py.Stream(stream_id_tweets)

# We then open a connection
#s_crypto.open()
s_tweets.open()

# Vader sentiment analyser
analyzer = SentimentIntensityAnalyzer()

class MyStreamer(TwythonStreamer):
    def on_success(self, data):
        if 'text' in data:
            # x value: date
            date_str = data['created_at']
            time_struct = time.strptime(date_str, "%a %b %d %H:%M:%S +0000 %Y")#Tue Apr 26 08:57:55 +0000 2011
            date = datetime.fromtimestamp(time.mktime(time_struct))
            
            # y value: sentiment of the tweet
            text = data['text']
            vs = analyzer.polarity_scores(text)
            score = vs["compound"] * (data["user"]["followers_count"]+1) * (data["favorite_count"]+1)
            
            s_tweets.write(dict(type='scatter',
                 x=date,y=score))

    def on_error(self, status_code, data):
        print(status_code, data)

        # Want to stop trying to get data because of the error?
        # Uncomment the next line!
        # self.disconnect()
        
APP_KEY = 'mPQKoRwd2Pb9qpQyQmyG5s8KR'
APP_SECRET = 'HLvIhusvfzDLKaRXY8CnZGP143kp3E3f2KqQBIEMfVL5mOxZjq'
OAUTH_TOKEN = "3459248236-0XPtHldG3ou6BfpTwaKWnOL2ywFk2niQekLwE7K"
OAUTH_TOKEN_SECRET = "08Vy2wuOkp7AmuC3rbjCHFJ94MLG2sWqdvGQtoiXmkVKr"

stream = MyStreamer(APP_KEY, APP_SECRET,
                    OAUTH_TOKEN, OAUTH_TOKEN_SECRET)
stream.statuses.filter(track=['#bitcoin', '#BTC'], lang='en')
# Out:
# 420 b'Easy there, Turbo. Too many requests recently. Enhance your calm.\r\n'
# 420 Unable to decode response,                                       not valid JSON.
# 420 b'Easy there, Turbo. Too many requests recently. Enhance your calm.\r\n'
# 420 Unable to decode response,                                       not valid JSON.
# RT @ethlend1: 🔥Development Update — What will happen during the next months?
# Find out what the ETHLend team will be working on:  the regula…
# ****************************
# #ORV #Orvium #science #peerreview #openscience #publishing #authors #research #Crypto #Blockchain #ether #ethereum… https://t.co/iwYfvnUL1H
# ****************************
# RT @Forte_token: THE Forte Token PROJECT
#
# SUPPLY : 200,000,000
# SYMBOL : FRT
#
# ETHEREUM BASE TOKEN
#
# WE ARE GIVING OVER 1  MILLION TOKEN AIRDR…
# ****************************
# $BTC giveaway by @kucoincom Exchange.
#
# Create an account if you haven't already:
# https://t.co/FMiPiXimfc
#
# Follow t… https://t.co/tHYjem11VY
# ****************************
# @FRESCO_NETWORK @georgewells77 @Chelsie1213 @B13RD @NeoClassicToken https://t.co/VC8wpExofa
# ****************************
# RT @slatecurrency: The Future of Entertainment is Now! @slatecurrency @CryptoCoinsNews
# #slate #slx #btc #eth #ltc
#
# https://t.co/AiT4AYi3Yg
# ****************************
# RT @KoronaCoin: 📰📉📈What is the technology innovation behind 👑Korona's ecosystem 1.0?
#
# 🌐https://t.co/TdvHuMq4fy
#
# #koronacoin #bitcoin #ether…
# ****************************
# RT @tatsizhakan: NEW #ICO #AIRDROP
#
# 🔥FREE 160 #HIT #TOKEN 🔥
#
#  https://t.co/6zcvYPbyfQ
#
# #btc #bitcoin #etherum #bth #ltc #XVGmag #bounty #ET…
# ****************************
# RT @BTCTN: Chinese Exchange Launching Southeast Asian Crypto Trading Hub https://t.co/gbHTjMuEh2 #Bitcoin https://t.co/NXl9Frf5f6
# ****************************
# RT @romad_antivirus: Why you should choose ROMAD Endpoint Defense?
# 📌Computers with already installed ROMAD antivirus were not attacked by P…
# ****************************
# RT @BitcoinAfricaio: A BIG WIN FOR #BITCOIN &amp; GOLIX -&gt; Zimbabwe High Court Suspends Ban on Cryptocurrencies Set by Central Bank - https://t…
# ****************************
# RT @ethlend1: 🔥Development Update — What will happen during the next months?
# Find out what the ETHLend team will be working on:  the regula…
# ****************************
# Robinhood App Valued at $5.6 Billion – Now Available in 10 US States https://t.co/FjlCHQnidl #bitcoin #blockchain… https://t.co/YMHjdMeIQR
# ****************************
# RT @ViewoOfficial: Join the Viewo Private Sale, Bounty and Airdrop today!
#
# The first GPU hosted true buffer-less video platform with encodi…
# ****************************
# https://t.co/DC8V6XfZ3R  22222 MJR👍💥🔥⚡️#airdrop #Airdrops #Bytecoin #Zilliqa #TRON #Ripple #ethereum #CARDANO… https://t.co/F3D8ML4Qz7
# ****************************
# RT @Crypto_Popo Robinhood App Valued at $5.6 Billion – Now Available in 10 US States https://t.co/D8Hwi0g6P5… https://t.co/RoUtkDArFH
# ****************************
# RT @BitNational: Shoutout to all our #Edmonton customers! We've got a new location at Stadium Mart - 9361 107A Ave NW. Swing in to buy/sell…
# ****************************
# RT @Cryptonomist_en: #Russia loves #bitcoin. A few major banks now want to launch an #ICO.
# https://t.co/z6txzx8WQl https://t.co/xOMWzWq4Mw
# ****************************
# RT @kucoincom: We are launching a new listing promotion together with @iotex_io! 5,000,000 IOTX + 5 BTC in total rewards!
#
# Details availabl…
# ****************************
# #tronixcash  #airdrop #bounty #BTC #xrp #bounty #Crypto #ETH #NEO #Blockchain #ripple #trx #tron #trx #binance… https://t.co/NlY2jKdNEO
# ****************************
# RT @Bicycle_coin: 1. Follow
# 2. Like
# 3. Retweet
# 4. Comment your ETH address
#
# #airdrop #bounty #freecoin #freetoken #cryptocurrency #crypt…
# ****************************
# RT @QWERTY44366488: Airdrop  in 96hrs
# 5000 following to start
#
# Name : QWERTY
# Symbol : QRY
# Total Supply : 50,000,000
# Listing Price : 0.3 U…
# ****************************
# RT @kucoincom: We are launching a new listing promotion together with @iotex_io! 5,000,000 IOTX + 5 BTC in total rewards!
#
# Details availabl…
# ****************************
# RT @tatsizhakan: NEW #ICO #AIRDROP
#
# 🔥 FREE 1000 #RGS #TOKEN 🔥
# (30 USD)
# https://t.co/lk3WRthPAl
#
# #btc #bitcoin #etherum #bth #ltc #XVGmag #b…
# ****************************
# RT @RedPillCoin: #REDPILLCOIN #REDPILL #ICO #BTC #ETH https://t.co/PtTl06lcSH
# ****************************
# 🔸 ¿Qué son las criptomonedas? El dinero virtual ya es una realidad #Bitcoin https://t.co/DOxfGRbozu
# ****************************
# @charlesaddey1 @Joba_Samuel @AleguJoseph @cryptodammy @Cryptolady7 @Maureen59106689 @ignusfatius @Mma5472… https://t.co/W7xlkzYIE5
# ****************************
# RT @XRPHODLER: #bankerscoin #Bitcoin https://t.co/8GU08w6A7Z
# ****************************
# RT @kucoincom: We are launching a new listing promotion together with @iotex_io! 5,000,000 IOTX + 5 BTC in total rewards!
#
# Details availabl…
# ****************************
# RT @Crypto_Pedians: Guys, you have to RT and FOLLOW!!!
# because i'm airdropping to 5 winners:
#
# 3 eth
# 35,000 trx
# 40,000 xvg
# 170,000 npxs
# 14…
# ****************************
# 👍👍👍 https://t.co/s8xTDxg1za
# ****************************
# +1 https://t.co/WEK7Kj3GKx
# ****************************
# RT @kingxchain: KingXChain are media partners with the world #blockchain forum event in New York on June 11-13. We hope to see you there! #…
# ****************************
# RT @cryptfunder: Cryptfunder is a decentralized funding source for startup ICOs and blockchain companies.
# https://t.co/mbjXRZduTR #cryptfun…
# ****************************
# #Yumerium #YUM #ethereum #bitcoin #cryptocurrency #btc
# 1 REFFERAL = 5000 ETT
#
#  #airdrop #bounty #BTC #xrp #freetoken #C…
# ****************************
# RT @Peurtoken: Enabling https://t.co/oXIXJbYU9R treasury wallet
#
# The Peur treasury wallet offers three layers of security protocols:
# • Fing…
# ****************************
# #CoinoneIndonesia is a family of #coinone the global top 10 crypto-exchange will launched on june. Pre-Registration… https://t.co/1bPZ6z0Sn6
# ****************************
# RT @WealthE_Coin: Want to learn more about #RealEstate #Investing? Check out this workshop with Clem Sunter! #WealthMigrate #WealthE #Block…
# ****************************
# RT @bechozun: See Co-Founder @teresatruda in action next week for @Blockchain_Conf talking all things #ICOs, the future of #blockchain &amp; #t…
# ****************************
# RT @ViewoOfficial: Join the Viewo Private Sale, Bounty and Airdrop today!
#
# The first GPU hosted true buffer-less video platform with encodi…
# ****************************
# RT @QWERTY44366488: Airdrop  in 96hrs
# 5000 following to start
#
# Name : QWERTY
# Symbol : QRY
# Total Supply : 50,000,000
# Listing Price : 0.3 U…
# ****************************
# RT @Autobayio: Have a great Sunday Autobayers!!! It's a nice day for a roadtrip!
#
# #SundayMotivation #SundayFunday #SundayBrunch #ico #icos…
# ****************************
# RT @Peurtoken: https://t.co/oXIXJbYU9R marketplace features only professional &amp; certified service providers.
#
# Our commitment to service pro…
# ****************************
# ✔️ DIGITALLY DURABLE
# ✔️ PORTABLE, SENDABLE
# ✔️ HIGHLY DIVISIBLE
# ✔️ DECENTRALIZED &amp; APOLITICAL
# ✔️ DIGITALLY SCARC… https://t.co/ecmrfvuIy8
# ****************************
# RT @superedge001: 🚀🚀SuperEdge Airdrop🚀🚀
#
# 10,0000ECT Free gift
# Retweet this and Follow us
# Please attention our website!
# https://t.co/6zFI3yl…
# ****************************
# Bitcoin Cash Price Analysis: BCH/USD Bearish Below $1,150 https://t.co/1ttDsUO7bl #wgcrypto #cloudmining #bitcoin #hashflare #bitconnect
# ****************************
# RT @AnatomiaToken: ANATOMIA (ATOM) is airdropping 10,000 ATOM tokens worth $500, you will  also earn 5,000 ATM tokens worth $250 by referri…
# ****************************
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-40-0a0c9d07fa11> in <module>()
#      47 stream = MyStreamer(APP_KEY, APP_SECRET,
#      48                     OAUTH_TOKEN, OAUTH_TOKEN_SECRET)
# ---> 49 stream.statuses.filter(track=['#bitcoin', '#BTC'], lang='en')
#
# /anaconda3/lib/python3.6/site-packages/twython/streaming/types.py in filter(self, **params)
#      65         url = 'https://stream.twitter.com/%s/statuses/filter.json' \
#      66               % self.streamer.api_version
# ---> 67         self.streamer._request(url, 'POST', params=params)
#      68
#      69     def sample(self, **params):
#
# /anaconda3/lib/python3.6/site-packages/twython/streaming/api.py in _request(self, url, method, params)
#     139             response = _send(retry_counter)
#     140
# --> 141             for line in response.iter_lines(self.chunk_size):
#     142                 if not self.connected:
#     143                     break
#
# /anaconda3/lib/python3.6/site-packages/requests/models.py in iter_lines(self, chunk_size, decode_unicode, delimiter)
#     795                 lines = chunk.split(delimiter)
#     796             else:
# --> 797                 lines = chunk.splitlines()
#     798
#     799             if lines and lines[-1] and chunk and lines[-1][-1] == chunk[-1]:
#
# KeyboardInterrupt:

# %%
# Close the stream when done plotting
s_tweets.close()
