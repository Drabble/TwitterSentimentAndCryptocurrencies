# %% [markdown]
# # Correlation analysis between the Bitcoin currency and Twitter
#
# This project consists of a correlation analysis between the Bitcoin currency and tweets. In order to define the positiveness of a tweet (if the course of the bitcoin will go up or down), we realise a sentiment analysis of each tweet using the VADER algorithm. Finally we try to find a correlation between the two and we will make some machine learning to make predictions.
#
# This notebook was written using Python 3.6.

# %% [markdown]
# ## Import the Python dependencies
# For this project we need Pandas to manage all of our datasets.
#
# You will need to run the following commands with pip to install the dependencies:
#
# ```
# pip install VaderSentiment
# pip install pandas
# pip install tqdm
# ...
# ```
#
# You can also run `pip install .` from the project's root folder to install all the requirements from the `requirements.txt` file.

# %%
import json
import pandas as pd
import io
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tnrange, tqdm_notebook, tqdm
import glob
from datetime import datetime

# %% [markdown]
# ## Set the currency and the data files

# %%
# Define the currency
CURRENCY = "zilliqa"
CURRENCY_SYMBOL = "ZIL"
#CURRENCY = "nexo"
#CURRENCY_SYMBOL = "NEXO"
#CURRENCY = "bitcoin"
#CURRENCY_SYMBOL = "BTC"


CRYPTO_FOLDER = f"data/crypto/{CURRENCY_SYMBOL}"
TWITTER_FOLDER = f"data/twitter/{CURRENCY_SYMBOL}"

tweets_clean_file = f'{TWITTER_FOLDER}/{CURRENCY}_tweets_clean.csv'

# %% [markdown]
# ## Load the datasets
# We read the data generated from two other notebooks, TwitterExtraction and CryptoCurrencyExtraction. The data is stored in 2 CSV files. The first one contains around 430'000 tweets all related to the Bitcoin on a period of 10 days between the 10.05.2018 and the 20.05.2018. The second dataset contains the historical data of the exchange rate between Bitcoin and USD over the same period of time.

# %%
tweets = pd.read_csv(tweets_clean_file)

# Drop duplicate tweets
print('tweet shape before droping duplicates', tweets.shape)
duplicates_removed = tweets.shape[0]
tweets = tweets.drop_duplicates(subset=['ID'])
duplicates_removed -= tweets.shape[0]
print('tweet shape after droping duplicates', tweets.shape)
print('duplicates removed', duplicates_removed)

tweets.head(5)
# Out:
# tweet shape before droping duplicates (14893, 7)
# tweet shape after droping duplicates (14730, 7)
# duplicates removed 163
#                     ID                                               Text  \
# 0  1001428255268917250  RT young_pfy5811 "$EOS 🚀🔥🚀🔥 The FUD is over!! ...
# 1  1001427808227414016  RT : Zilliqa Project Update 9 is available her...
# 2  1001427793006166017  We will pump on binance at 10PM/MXL2WCQ35r$BQX...
# 3  1001427581588135936  RT : Babb is my choice for the next run ! $bax...
# 4  1001426794589949952  Cryptocurrecy trading terms 🧐💪For all cypto co...
#
#            UserName  UserFollowerCount  RetweetCount  Likes  \
# 0         Ira Cohen               4218             0      0
# 1  Guido Santa Cruz                 47           100      0
# 2       Elliott Har                 12             0      0
# 3   Morpheus Nation                 44             7      0
# 4      Braveheart22                875             0      2
#
#                         CreatedAt
# 0  Tue May 29 11:41:16 +0000 2018
# 1  Tue May 29 11:39:29 +0000 2018
# 2  Tue May 29 11:39:26 +0000 2018
# 3  Tue May 29 11:38:35 +0000 2018
# 4  Tue May 29 11:35:28 +0000 2018

# %%
crypto_files = glob.glob(f"{CRYPTO_FOLDER}/*.csv")
dfs = []
for file in crypto_files:
    dfs.append(pd.read_csv(file))
crypto_usd = pd.concat(dfs)
crypto_usd = crypto_usd.sort_values(by=['time'])

# Drop duplicates
print('bitcoin shape before droping duplicates', crypto_usd.shape)
duplicates_removed = crypto_usd.shape[0]
crypto_usd = crypto_usd.drop_duplicates(subset=['time'])
print('bitcoin shape after droping duplicates', crypto_usd.shape)
duplicates_removed -= crypto_usd.shape[0]
print('duplicates removed', duplicates_removed)
crypto_usd.head(5)
# Out:
# bitcoin shape before droping duplicates (15829, 5)
# bitcoin shape after droping duplicates (15820, 5)
# duplicates removed 9
#     close    high     low    open        time
# 0  0.1340  0.1342  0.1338  0.1340  1526645280
# 1  0.1340  0.1340  0.1339  0.1340  1526645340
# 2  0.1342  0.1342  0.1340  0.1341  1526645400
# 3  0.1341  0.1341  0.1339  0.1341  1526645460
# 4  0.1340  0.1341  0.1339  0.1340  1526645520

# %% [markdown]
# ## Sentiment analysis
#
# ### VADER
# VADER (Valence Aware Dictionary and sEntiment Reasoner) is a lexicon and rule-based sentiment analysis tool that is specifically attuned to sentiments expressed in social media.
#
# VADER takes into account
# - negations and contractions (not good, wasn’t good)
# - Ponctuation (good!!!), CAPS, emotes :), emojis
# - Intensificators (very, kind of), acronyms ‘lol’
# - Scores between -1.0 (negative) and 1.0 (positive)
#
# We will use this sentiment analysis of the tweets to calculate a score that will represent the importance of each tweet.

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()
compound = []
for i,s in enumerate(tqdm(tweets['Text'])):
    vs = analyzer.polarity_scores(s)
    compound.append(vs["compound"])
tweets["compound"] = compound
tweets.head(5)
# Out:
# 100%|██████████| 14730/14730 [00:03<00:00, 3730.80it/s]
#                     ID                                               Text  \
# 0  1001428255268917250  RT young_pfy5811 "$EOS 🚀🔥🚀🔥 The FUD is over!! ...
# 1  1001427808227414016  RT : Zilliqa Project Update 9 is available her...
# 2  1001427793006166017  We will pump on binance at 10PM/MXL2WCQ35r$BQX...
# 3  1001427581588135936  RT : Babb is my choice for the next run ! $bax...
# 4  1001426794589949952  Cryptocurrecy trading terms 🧐💪For all cypto co...
#
#            UserName  UserFollowerCount  RetweetCount  Likes  \
# 0         Ira Cohen               4218             0      0
# 1  Guido Santa Cruz                 47           100      0
# 2       Elliott Har                 12             0      0
# 3   Morpheus Nation                 44             7      0
# 4      Braveheart22                875             0      2
#
#                         CreatedAt  compound
# 0  Tue May 29 11:41:16 +0000 2018   -0.6145
# 1  Tue May 29 11:39:29 +0000 2018    0.0000
# 2  Tue May 29 11:39:26 +0000 2018    0.0000
# 3  Tue May 29 11:38:35 +0000 2018    0.0000
# 4  Tue May 29 11:35:28 +0000 2018    0.6369

# %% [markdown]
# ### Calculate a score for each tweet
# To calculate the score for each tweet, we use different variables to which we had a weight based on its importance.
#
# The compound column represents the sentiment of the tweets and its value is between -1 and 1.
#
# We also use the number of retweets, the number of likes, and the number of users that follow the tweet's author.

# %%
scores = []
for i, s in tqdm(tweets.iterrows(), total=tweets.shape[0]):
    scores.append(s["compound"] * ((s["UserFollowerCount"]+1)) * ((s["Likes"]+1)))
tweets["Scores"] = scores
tweets.head(5)
# Out:
# 100%|██████████| 14730/14730 [00:01<00:00, 12128.64it/s]
#                     ID                                               Text  \
# 0  1001428255268917250  RT young_pfy5811 "$EOS 🚀🔥🚀🔥 The FUD is over!! ...
# 1  1001427808227414016  RT : Zilliqa Project Update 9 is available her...
# 2  1001427793006166017  We will pump on binance at 10PM/MXL2WCQ35r$BQX...
# 3  1001427581588135936  RT : Babb is my choice for the next run ! $bax...
# 4  1001426794589949952  Cryptocurrecy trading terms 🧐💪For all cypto co...
#
#            UserName  UserFollowerCount  RetweetCount  Likes  \
# 0         Ira Cohen               4218             0      0
# 1  Guido Santa Cruz                 47           100      0
# 2       Elliott Har                 12             0      0
# 3   Morpheus Nation                 44             7      0
# 4      Braveheart22                875             0      2
#
#                         CreatedAt  compound     Scores
# 0  Tue May 29 11:41:16 +0000 2018   -0.6145 -2592.5755
# 1  Tue May 29 11:39:29 +0000 2018    0.0000     0.0000
# 2  Tue May 29 11:39:26 +0000 2018    0.0000     0.0000
# 3  Tue May 29 11:38:35 +0000 2018    0.0000     0.0000
# 4  Tue May 29 11:35:28 +0000 2018    0.6369  1673.7732

# %%
tweets.tail(100)
# Out:
#                        ID                                               Text  \
# 14792  997857765614747649  RT : $ZIL breaking out from the massive fallin...
# 14793  997857697964986368  RT : Giveaway 25Poll: Coinbase will list ___.W...
# 14794  997857658391728131  RT : Giveaway 25Poll: Coinbase will list ___.W...
# 14795  997857620445687810  RT : We are pleased to announce that we will l...
# 14796  997857457488744448  RT : Giveaway 25Poll: Coinbase will list ___.W...
# 14797  997857419630821377  RT : lol i did that once during my PhD time, m...
# 14798  997857358125580288  RT : My viewers are so awesome! Thanks for the...
# 14799  997857279574601734  RT : We are pleased to announce that we will l...
# 14800  997857273144840193  Tomorrow Events 20.5.2018$XSN $BELA $BIOT $BBP...
# 14801  997857045591273475  $ENJ and $ZIL are both doing well for me atm. ...
# 14802  997856976452268034                                         Good work!
# 14803  997856911398584320  RT : A familiar sight for us whenever we do la...
# 14804  997856833145638912  RT : It's Saturday night but the team is still...
# 14805  997856525925388288    Like the look of green $ZIL again 🙌 /UmH4iI5Cbv
# 14806  997856429624131584  RT : It's Saturday night but the team is still...
# 14807  997856340130324480  Market Cap: 379,919,736,040 $We checked! Binan...
# 14808  997856292851994624  RT : $ZIL breaking out from the massive fallin...
# 14809  997856264800514049                       Yep, $zil re-buys going low.
# 14810  997856234970628097  RT : It's Saturday night but the team is still...
# 14811  997856184165060610  RT : We are pleased to announce that we will l...
# 14812  997856161893441536  New at Betfirst ? Transfer €50 and get €150 !!...
# 14813  997856047154032642  RT : A familiar sight for us whenever we do la...
# 14814  997855973694955520  RT : It's Saturday night but the team is still...
# 14815  997855748519579648  RT : /EV1VcxxRbyBithumb lists Zilliqa (ZIL) an...
# 14816  997855729620078593  RT : SPARKSTER $SPARK SPARK  🚀🚀3x Faster Then ...
# 14817  997855665237430273  BITMEX is where i traded and fcking doubled my...
# 14818  997855617321549824  RT : A familiar sight for us whenever we do la...
# 14819  997855490955759616  $PCN now up more than 900% since my call on it...
# 14820  997855483288571908  $GVT / BTC +3.052%UP$NEBL / BTC +1.01%UP$WPR /...
# 14821  997855112306438144  RT : $ZIL breaking out from the massive fallin...
# ...                   ...                                                ...
# 14863  997851717608902656                                  excellent project
# 14864  997851464914653186  RT : It's Saturday night but the team is still...
# 14865  997851122269376513                                    $ZIL bull run !
# 14866  997851003369111553  RT : It's Saturday night but the team is still...
# 14867  997850936885248006  RT : $ZIL breaking out from the massive fallin...
# 14868  997850887270883328            Zil is a hungry beast! This is awesome.
# 14869  997850792529940480  Buy this coin in Binance right now!Possible pr...
# 14870  997850302345773056  RT : $ZIL breaking out from the massive fallin...
# 14871  997850003254202370  Hanging up the learning boots for today. Ready...
# 14872  997849949067980805  RT : It's Saturday night but the team is still...
# 14873  997849940721373184  RT : NEW on the Enigma blog: "Oops, We Brought...
# 14874  997849694465380352  There’s so much good news circling ZIL ❇️  Sci...
# 14875  997849670599704581  RT : It's Saturday night but the team is still...
# 14876  997849335554592770  RT : NEW on the Enigma blog: "Oops, We Brought...
# 14877  997848279743262721  RT : We are pleased to announce that we will l...
# 14878  997848202450792449  Warren go to the beach relax ... a new era is ...
# 14879  997848133575950336  BITMEX is where i traded and fcking doubled my...
# 14880  997848125044854784  RT : $ZIL breaking out from the massive fallin...
# 14881  997847529487327234  RT : $ZIL breaking out from the massive fallin...
# 14882  997847516824485888  RT : We are pleased to announce that we will l...
# 14883  997847264969285632  Unocoin announces listing for Golem [GNT], Zil...
# 14884  997847256291307521  $DASH Dash price: $398.58 Binance has stop los...
# 14885  997846878954778624  RT : $ZIL breaking out from the massive fallin...
# 14886  997846738269589505  RT : /EV1VcxxRbyBithumb lists Zilliqa (ZIL) an...
# 14887  997846615074443265  RT : $ZIL breaking out from the massive fallin...
# 14888  997846462959628288  RT : $ZIL breaking out from the massive fallin...
# 14889  997846400904839168  RT : $ZIL breaking out from the massive fallin...
# 14890  997846131509006336  Monero $XMR price: $200.48 Binance has over 3 ...
# 14891  997846005507702785  RT : $ZIL breaking out from the massive fallin...
# 14892  997845893440253952  RT : Zilliqa(ZIL) trading now LIVE on Unocoin ...
#
#                                     UserName  UserFollowerCount  RetweetCount  \
# 14792                            Ashim Kumar                 92            83
# 14793                            Raskolnikov                 47           494
# 14794                          Rekt In Space                 87           494
# 14878      0  Sat May 19 14:35:25 +0000 2018    0.4926     116.2536
# 14879      1  Sat May 19 14:35:08 +0000 2018    0.2732       9.8352
# 14880      0  Sat May 19 14:35:06 +0000 2018    0.2732      18.8508
# 14881      0  Sat May 19 14:32:44 +0000 2018    0.2732      31.1448
# 14882      0  Sat May 19 14:32:41 +0000 2018    0.6249      55.6161
# 14883      0  Sat May 19 14:31:41 +0000 2018    0.0000       0.0000
# 14884      0  Sat May 19 14:31:39 +0000 2018    0.4199       5.8786
# 14885      0  Sat May 19 14:30:09 +0000 2018    0.2732       7.3764
# 14886      0  Sat May 19 14:29:36 +0000 2018    0.0000       0.0000
# 14887      0  Sat May 19 14:29:06 +0000 2018    0.2732     246.1532
# 14888      0  Sat May 19 14:28:30 +0000 2018    0.2732       2.4588
# 14889      0  Sat May 19 14:28:15 +0000 2018    0.2732       5.1908
# 14890      0  Sat May 19 14:27:11 +0000 2018    0.4184      17.1544
# 14891      0  Sat May 19 14:26:41 +0000 2018    0.2732      19.3972
# 14892      0  Sat May 19 14:26:14 +0000 2018    0.0000       0.0000
#
# [100 rows x 9 columns]

# %% [markdown]
# ## Group by and sum by 5 minutes

# %%
tweets['CreatedAt'] = pd.to_datetime(tweets['CreatedAt'])
tweets.index = tweets['CreatedAt']

tweets_grouped = tweets.groupby(pd.TimeGrouper('1h'))['Scores'].sum()

crypto_usd['time'] = pd.to_datetime(crypto_usd['time'], unit='s')
crypto_usd.index = crypto_usd['time']

crypto_usd_grouped = crypto_usd.groupby(pd.TimeGrouper('1h'))['close'].mean()

# %% [markdown]
# ### Plotting the scores
# We calculate the mean of each tweets grouped by hour and then we plot it.

# %%
#
#plt.plot_date(tweets_grouped.index, tweets_grouped, ls='-', marker='o')
#plt.plot_date(crypto_usd_grouped.index, crypto_usd_grouped, ls='-', marker='o')
#plt.show()

fig, ax1 = plt.subplots(figsize=(20,10))

ax2 = ax1.twinx()
ax1.plot_date(tweets_grouped.index, tweets_grouped, 'g-')
ax2.plot_date(crypto_usd_grouped.index, crypto_usd_grouped, 'b-')

ax1.set_xlabel('X data')
ax1.set_ylabel('Y1 data', color='g')
ax2.set_ylabel('Y2 data', color='b')
plt.show()

# %% [markdown]
# ## Correlation analysis
# Here we make the correlation analysis between BTC/USD currency derivative and the tweets scores derivative.
#
# We can test our correlation hypothesis using the Pandas corr() method, which computes a Pearson correlation coefficient for each column in the dataframe against each other column.
#
# This Stackoverflow answer gives very useful details about correlating with time series.
# https://stackoverflow.com/questions/6467832/how-to-get-the-correlation-between-two-timeseries-using-pandas

# %%
tweets_grouped.corr(crypto_usd_grouped)
# Out:
# 0.113177759908923

# %% [markdown]
# ### Derivative and offset
# We will need a bit more complicated correlation analysis here as we need to correlate the derivative of both series and we will need to offset each serie from the other because the change increase in the Bitcoin currency should occure a few moments after the tweets. The task here is to find a good offset.

# %%
#Derivative and normalisation???

#Offset

#Correlation
